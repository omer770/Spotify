# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np

# %%
import gdown
url = "https://drive.google.com/file/d/1OD5o45MzKubH_vddsy8v_s3KXE43CxvD/view?usp=drive_link"
id = url.split("/")[-2]
gdown.download(id=id ,quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1OD5o45MzKubH_vddsy8v_s3KXE43CxvD
# To: /content/spotify_data.csv
# 100%|██████████| 176M/176M [00:01<00:00, 109MB/s]
# 'spotify_data.csv'

# %%
df = pd.read_csv('spotify_data.csv')
df
# Out:
#          Unnamed: 0      artist_name                         track_name  \
# 0                 0       Jason Mraz                    I Won't Give Up
# 1                 1       Jason Mraz                   93 Million Miles
# 2                 2    Joshua Hyslop                   Do Not Let Me Go
# 3                 3     Boyce Avenue                           Fast Car
# 4                 4     Andrew Belle                   Sky's Still Blue
# ...             ...              ...                                ...
# 1159759     1473391     Nicola Conte                      Black Spirits
# 1159760     1473392     Nicola Conte                         Quiet Dawn
# 1159761     1473393       Amon Tobin                  Morning Ms Candis
# 1159762     1473394  Peace Orchestra      Happy Christmas (War Is Over)
# 1159763     1473395     Mo' Horizons  Hit the Road Jack (Pé Na Éstrada)
#
#                        track_id  popularity  year     genre  danceability  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'year', 'genre', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
unique_artists = df['artist_name'].unique()
num_uniue_artists = df['artist_name'].nunique()
print(f"Number of  Unique artists: {num_uniue_artists}")
# Out:
# Number of  Unique artists: 64159

# %%
average_popularity = df['popularity'].mean()
print(f"Average Popularity : {average_popularity}")
# Out:
# Average Popularity : 18.38312277325387

# %%
max_popularity = df['popularity'].max()
max_popularity_track = df[df['popularity'] == max_popularity][['track_name', 'artist_name']]
print("Max popularity track:")
print(max_popularity_track)
# Out:
# Max popularity track:
#        track_name  artist_name
# 612503    Flowers  Miley Cyrus

# %%
df[df['popularity'] >87][['track_name', 'artist_name','popularity']]
# Out:
#                                                track_name        artist_name  \
# 77591                                    I Wanna Be Yours     Arctic Monkeys
# 350200                                  I Was Never There         The Weeknd
# 377663                                Under The Influence        Chris Brown
# 461991                                    Blinding Lights         The Weeknd
# 541577                                    I'm Good (Blue)       David Guetta
# 541578                                          Escapism.               RAYE
# 541579                                            CUFF IT            Beyoncé
# 541580                                           Nonsense  Sabrina Carpenter
# 541581                                      Made You Look     Meghan Trainor
# 541582                                              10:35             Tiësto
# 549416                                           ceilings     Lizzy McAlpine
# ...

# %% [markdown]
# ###Popularity distribution

# %%
import matplotlib.pyplot as plt

plt.hist(df['popularity'], bins=15)
plt.xlabel('Popularity')
plt.ylabel('Count')
plt.title('Distribution of Popularity')
plt.show()

# %%
genre_counts = df['genre'].value_counts()
print("Genre counts:")
print(genre_counts)
# Out:
# Genre counts:
# black-metal       21852
# gospel            21621
# ambient           21389
# acoustic          21097
# alt-rock          20918
#                   ...
# chicago-house      5170
# dubstep            4774
# detroit-techno     3920
# rock               3319
# songwriter          589
# Name: genre, Length: 82, dtype: int64

# %%
average_danceability = df['danceability'].mean()
average_energy = df['energy'].mean()
print("Average danceability:", average_danceability)
print("Average energy:", average_energy)
# Out:
# Average danceability: 0.5374382319161484
# Average energy: 0.6396698993142569

# %%
key_counts = df['key'].value_counts()
print("Key counts:")
print(key_counts)
# Out:
# Key counts:
# 7     139635
# 0     130081
# 2     123690
# 9     119293
# 1     112806
# 5      94032
# 4      91170
# 11     90955
# 6      76120
# 10     76038
# 8      70206
# 3      35738
# Name: key, dtype: int64

# %%
genre_counts = df['genre'].value_counts()
plt.figure(figsize=(15, 6))
plt.bar(genre_counts.index, genre_counts.values)
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Genre Counts')
plt.xticks(rotation=90)
plt.show()

# %%
artist_counts = df['artist_name'].value_counts()[:100]
plt.figure(figsize=(15, 6))
plt.bar(artist_counts.index, artist_counts.values)
plt.xlabel('Artist_names')
plt.ylabel('Count')
plt.title('Artist Counts')
plt.xticks(rotation=90)
plt.show()

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# artist_name          object
# track_name           object
# track_id             object
# popularity            int64
# year                  int64
# genre                object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature        int64
# dtype: object

# %%
df['mode'].value_counts()
# Out:
# 1    736048
# 0    423716
# Name: mode, dtype: int64

# %%
df1 = df.loc[:,['artist_name', 'track_name', 'genre', 'danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness','valence', 'tempo', 'duration_ms', 'time_signature', 'popularity']].copy()

# %%
df1.head()
# Out:
#      artist_name        track_name     genre  danceability  energy  key  \
# 0     Jason Mraz   I Won't Give Up  acoustic         0.483   0.303    4
# 1     Jason Mraz  93 Million Miles  acoustic         0.572   0.454    3
# 2  Joshua Hyslop  Do Not Let Me Go  acoustic         0.409   0.234    3
# 3   Boyce Avenue          Fast Car  acoustic         0.392   0.251   10
# 4   Andrew Belle  Sky's Still Blue  acoustic         0.430   0.791    6
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   -10.058     1       0.0429        0.6940          0.000000    0.1150
# 1   -10.286     1       0.0258        0.4770          0.000014    0.0974
# 2   -13.711     1       0.0323        0.3380          0.000050    0.0895
# 3    -9.845     1       0.0363        0.8070          0.000000    0.0797
# 4    -5.419     0       0.0302        0.0726          0.019300    0.1100
#
#    valence    tempo  duration_ms  time_signature  popularity
# ...

# %%
df1["duration"] = df1.duration_ms/1000

# %%
artists = list(df1.sort_values("popularity",ascending=False)["artist_name"].unique())
artists.reverse()

# %%
artists
# Out:
# ['Sines',
#  'Jamie Vexd',
#  'Saleem Razvi',
#  'Ghost Note',
#  'Jus Wan',
#  'Audiophile 021',
#  'Igness',
#  'El Rakkas',
#  'Planas',
#  'Cogent',
#  'Caustik',
#  'Cauto',
#  'Lures',
#  'Zero Boys',
#  "De'Lacy",
#  'The Standells',
#  'Phase II',
#  'Nekochan',
#  'Orchestra del Teatro Comunale di Bologna',
#  'Grace Bumbry',
#  'Mission',
#  'Weena',
#  'Sylvi Alli',
#  'Daylight Torn',
#  'Reclusion',
#  'Immersed in Blood',
#  'DJ Hoax',
#  'The Next',
#  'Likhan',
#  'Mr.Boogie',
#  'Acrylite',
#  'Burnkane',
#  'Substacja',
#  'Dave Shichman',
#  'Kaskaad',
#  'Biscope',
#  'Sollabong',
#  'DJ Enme',
#  'Apathesis',
#  'DJ Johnny Beast',
#  'Polaki',
#  'Merel',
#  'Latenta Project',
#  'A Month of Somedays',
#  'Day Action Band',
#  'Radio Flyer',
#  '1.6 Band',
#  'The Operation',
#  'Garden Variety',
#  'Lock and Key Theory',
#  'Mid Carson July',
#  'Mokira',
#  'Yasus Afari',
#  'The Jinks',
#  'Jose Escribano',
#  'Tellusian',
#  'Bingo',
#  'Madhup Mudgal',
# ...

# %%
len(artists)
# Out:
# 64159

# %%
df1["popularity"] = df1["popularity"]/100

# %%
genre_list = list(df1.sort_values("popularity",ascending=False)["genre"].unique())
genre_list.reverse()

# %%
import seaborn as sns

# %%
genre_list
# Out:
# ['romance',
#  'dubstep',
#  'grindcore',
#  'tango',
#  'metalcore',
#  'detroit-techno',
#  'power-pop',
#  'trip-hop',
#  'opera',
#  'rock-n-roll',
#  'new-age',
#  'black-metal',
#  'guitar',
#  'breakbeat',
#  'minimal-techno',
#  'progressive-house',
#  'dancehall',
#  'ska',
#  'heavy-metal',
#  'industrial',
#  'songwriter',
#  'punk-rock',
#  'goth',
#  'drum-and-bass',
#  'death-metal',
#  'techno',
#  'samba',
#  'trance',
#  'electronic',
#  'party',
#  'dub',
#  'groove',
#  'afrobeat',
#  'swedish',
#  'salsa',
#  'classical',
#  'comedy',
#  'hardcore',
#  'psych-rock',
#  'deep-house',
#  'gospel',
#  'cantopop',
#  'spanish',
#  'show-tunes',
#  'punk',
#  'blues',
#  'pop-film',
#  'chicago-house',
#  'jazz',
#  'singer-songwriter',
#  'disco',
#  'soul',
#  'acoustic',
#  'hard-rock',
#  'forro',
#  'indian',
#  'ambient',
#  'edm',
#  'french',
#  'house',
#  'chill',
#  'german',
#  'club',
#  'hardstyle',
#  'alt-rock',
#  'funk',
#  'metal',
#  'emo',
# ...

# %%
df1.columns
# Out:
# Index(['artist_name', 'track_name', 'genre', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
#        'popularity', 'duration'],
#       dtype='object')

# %%
plt.scatter(df1.loudness,df1.popularity)

# %%
plt.scatter(df1.instrumentalness,df1.popularity)

# %%
plt.scatter(df1.speechiness,df1.popularity)

# %%
df_sub_gen = df.loc[:,["popularity","genre"]]
df_sub_gen = df_sub_gen.groupby(["genre"]).mean().sort_values(by=["popularity"],ascending= False )
genre_sel  = df_sub_gen[df_sub_gen["popularity"]>25].index
df_sub_gen
# Out:
#                 popularity
# genre
# pop              55.685806
# hip-hop          46.315736
# rock             46.228985
# dance            43.034337
# metal            39.698860
# ...                    ...
# chicago-house     3.260542
# detroit-techno    2.953827
# grindcore         2.647805
# tango             2.523326
# romance           0.659405
#
# [82 rows x 1 columns]

# %%
df_sub_art = df.loc[:,["popularity","artist_name"]]
df_sub_art = df_sub_art.groupby(["artist_name"]).mean().sort_values(by=["popularity"],ascending= False )
artist_sel  = df_sub_art[df_sub_art["popularity"]>60].index
df_sub_art
# Out:
#                        popularity
# artist_name
# NewJeans                85.333333
# Elley Duhé              85.000000
# Rema                    80.666667
# Chani Nattan            80.000000
# SunKissed Lola          80.000000
# ...                           ...
# Third Sovereign          0.000000
# Dark Franklin            0.000000
# Dark Filth Fraternity    0.000000
# Dark Blonde Elektric     0.000000
# Overdream                0.000000
#
# [64159 rows x 1 columns]

# %%
artist_sel
# Out:
# Index(['NewJeans', 'Elley Duhé', 'Rema', 'Chani Nattan', 'SunKissed Lola',
#        'Jogja Hip Hop Foundation', 'Fujii Kaze', 'Cian Ducrot', 'Oxlade',
#        'Jung Kook',
#        ...
#        'Kweller', 'Lomepal', 'OFFICIAL HIGE DANDISM', 'PARTYNEXTDOOR',
#        'Braaheim', 'Pashanim', 'Strawberry Guy', 'Sainté', '88rising',
#        'Lefty Sm'],
#       dtype='object', name='artist_name', length=644)

# %%
df2 = df1.loc[:,['artist_name','genre', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'time_signature', 'duration','popularity']]

# %%
df2.head()
# Out:
#      artist_name     genre  danceability  energy  key  loudness  mode  \
# 0     Jason Mraz  acoustic         0.483   0.303    4   -10.058     1
# 1     Jason Mraz  acoustic         0.572   0.454    3   -10.286     1
# 2  Joshua Hyslop  acoustic         0.409   0.234    3   -13.711     1
# 3   Boyce Avenue  acoustic         0.392   0.251   10    -9.845     1
# 4   Andrew Belle  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0429        0.6940          0.000000    0.1150    0.139  133.406
# 1       0.0258        0.4770          0.000014    0.0974    0.515  140.182
# 2       0.0323        0.3380          0.000050    0.0895    0.145  139.832
# 3       0.0363        0.8070          0.000000    0.0797    0.508  204.961
# 4       0.0302        0.0726          0.019300    0.1100    0.217  171.864
#
#    time_signature  duration  popularity
# 0               3   240.166        0.68
# ...

# %%
artist_sel
# Out:
# Index(['NewJeans', 'Elley Duhé', 'Rema', 'Chani Nattan', 'SunKissed Lola',
#        'Jogja Hip Hop Foundation', 'Fujii Kaze', 'Cian Ducrot', 'Oxlade',
#        'Jung Kook',
#        ...
#        'Kweller', 'Lomepal', 'OFFICIAL HIGE DANDISM', 'PARTYNEXTDOOR',
#        'Braaheim', 'Pashanim', 'Strawberry Guy', 'Sainté', '88rising',
#        'Lefty Sm'],
#       dtype='object', name='artist_name', length=644)

# %%
artist_sel =list(artist_sel)
artist_sel.append("Other")
artist_sel.reverse()

# %%
id_2_art = dict((i,j) for i,j in enumerate(artist_sel))
art_2_id = dict((j,i) for i,j in enumerate(artist_sel))

# %%
df2["artist_id"] =df2.artist_name.map(art_2_id)
df2 = df2.fillna(0)

# %%
genre_sel=list(genre_sel)
genre_sel.append("Other")
genre_sel.reverse()

# %%
id_2_gen = dict((i,j) for i,j in enumerate(genre_sel))
gen_2_id = dict((j,i) for i,j in enumerate(genre_sel))

# %%
df2["genre_id"] = df2.genre.map(gen_2_id)

# %%
df2 = df2.fillna(0)

# %%
df2.head()
# Out:
#      artist_name     genre  danceability  energy  key  loudness  mode  \
# 0     Jason Mraz  acoustic         0.483   0.303    4   -10.058     1
# 1     Jason Mraz  acoustic         0.572   0.454    3   -10.286     1
# 2  Joshua Hyslop  acoustic         0.409   0.234    3   -13.711     1
# 3   Boyce Avenue  acoustic         0.392   0.251   10    -9.845     1
# 4   Andrew Belle  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0429        0.6940          0.000000    0.1150    0.139  133.406
# 1       0.0258        0.4770          0.000014    0.0974    0.515  140.182
# 2       0.0323        0.3380          0.000050    0.0895    0.145  139.832
# 3       0.0363        0.8070          0.000000    0.0797    0.508  204.961
# 4       0.0302        0.0726          0.019300    0.1100    0.217  171.864
#
#    time_signature  duration  popularity  artist_id  genre_id
# ...

# %%
df3 = df2.loc[:,['artist_id', 'genre_id','duration','key', 'loudness','tempo', 'time_signature','danceability',
                 'energy','speechiness', 'acousticness', 'instrumentalness', 'liveness','valence' ,'popularity']]

# %%
df3
# Out:
#          artist_id  genre_id  duration  key  loudness    tempo  \
# 0              0.0       0.0   240.166    4   -10.058  133.406
# 1              0.0       0.0   216.387    3   -10.286  140.182
# 2              0.0       0.0   158.960    3   -13.711  139.832
# 3              0.0       0.0   304.293   10    -9.845  204.961
# 4              0.0       0.0   244.320    6    -5.419  171.864
# ...            ...       ...       ...  ...       ...      ...
# 1159759        0.0       0.0   344.013   10    -6.453  107.951
# 1159760        0.0       0.0   285.067    7    -7.588  119.897
# 1159761        0.0       0.0   214.253    5    -8.512  100.076
# 1159762        0.0       0.0   239.133    0   -13.343  133.885
# 1159763        0.0       0.0   212.227    1    -7.292   89.987
#
#          time_signature  danceability  energy  speechiness  acousticness  \
# 0                     3         0.483   0.303       0.0429        0.6940
# ...

# %%
#df3["genre_id"] = df2.genre_id.map(id_2_gen)

# %%
#df4 = pd.merge(df3,pd.get_dummies(df3["genre_id"]),left_index = True,right_index=True).drop(["genre_id"] ,axis = 1)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
mm_sc = MinMaxScaler()

# %%
from sklearn.model_selection import train_test_split

# %%
X = df3.iloc[:,:-1].values
y = list(df3.popularity.values)

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
len(X_train),len(X_test)
# Out:
# (1043787, 115977)

# %%
X_train[:5]
# Out:
# array([[ 0.00000e+00,  0.00000e+00,  2.89536e+02,  9.00000e+00,
#         -6.50500e+00,  1.67499e+02,  4.00000e+00,  3.59000e-01,
#          7.43000e-01,  4.65000e-02,  5.96000e-01,  0.00000e+00,
#          3.59000e-01,  6.94000e-01],
#        [ 0.00000e+00,  0.00000e+00,  2.25672e+02,  6.00000e+00,
#         -3.82500e+00,  1.54027e+02,  4.00000e+00,  6.50000e-01,
#          7.92000e-01,  3.93000e-02,  6.07000e-01,  2.36000e-05,
#          9.20000e-01,  8.72000e-01],
#        [ 0.00000e+00,  0.00000e+00,  7.55070e+01,  1.00000e+00,
#         -1.38420e+01,  1.10292e+02,  4.00000e+00,  5.00000e-01,
#          2.76000e-01,  3.63000e-02,  9.19000e-01,  4.73000e-05,
#          2.36000e-01,  6.19000e-01],
#        [ 0.00000e+00,  0.00000e+00,  4.52787e+02,  0.00000e+00,
#         -4.56500e+00,  1.30053e+02,  4.00000e+00,  3.92000e-01,
#          8.17000e-01,  3.78000e-02,  1.51000e-04,  1.50000e-02,
#          3.72000e-01,  1.86000e-01],
# ...

# %%
X_train = mm_sc.fit_transform(X_train)

# %%
X_test = mm_sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import cross_val_score

# %%
regression = LinearRegression()

# %%
regression2 = DecisionTreeRegressor()

# %%
#mse = cross_val_score(regression1,X_train,y_train,scoring="neg_mean_squared_error",cv = 10)
#np.mean(mse)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression2.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = regression.predict(X_test)
y_pred2 = regression2.predict(X_test)

# %%
import seaborn as sns
sns.displot(y_pred-y_test,kind="kde")#less variation

# %%
sns.displot(y_pred2-y_test,kind="kde")#less variation

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)
score2 = r2_score(y_test, y_pred2)
print("The accuracy of our Linear regression model is {}%".format(round(score, 2) *100))
print("The accuracy of our Decision Tree regression model is {}%".format(round(score2, 2) *100))
# Out:
# The accuracy of our Linear regression model is 31.0%
# The accuracy of our Decision Tree regression model is -19.0%
